# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('D://DKIT//dissertation//Dataset_of_Tomato_Leaves//plantvillage//Preprocessed_data//32//vector//')

# %%
rgb_data = np.load('rgb_data.npy')

# %%
print(gray_data.shape)
# Out:
# (14531, 3072)

# %%
rgb_df = pd.Data

# %%
gray_dataframe = pd.DataFrame(gray_data,columns=cols)

# %%
gray_dataframe
# Out:
#        pixel_0  pixel_1  pixel_2  pixel_3  pixel_4  pixel_5  pixel_6  pixel_7  \
# 0          143      147      146      147      149      148      149      149
# 1          174      170      159      172      168      159      170      165
# 2          130      129      111      127      128      112      124      127
# 3          132      126      128      131      125      127      126      120
# 4          163      174      170      164      173      170      166      172
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 14526      130      118      120      133      121      123      138      123
# 14527      121      120      126      125      122      129      129      124
# 14528      130      117      124      131      118      125      133      120
# 14529      167      160      167      170      163      170      175      165
# 14530      108       98       96      108       98       96      109       97
#
# ...

# %%
gray_dataframe.describe()
# Out:
#             pixel_0       pixel_1       pixel_2       pixel_3       pixel_4  \
# count  14531.000000  14531.000000  14531.000000  14531.000000  14531.000000
# mean     138.317872    132.691005    135.624183    138.626041    132.643796
# std       31.158835     30.696443     32.836212     31.010586     30.478228
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      120.000000    113.000000    114.000000    120.000000    113.000000
# 50%      138.000000    133.000000    136.000000    138.000000    133.000000
# 75%      157.000000    151.000000    156.000000    157.000000    151.000000
# max      255.000000    249.000000    255.000000    252.000000    246.000000
#
#             pixel_5       pixel_6       pixel_7       pixel_8       pixel_9  \
# count  14531.000000  14531.000000  14531.000000  14531.000000  14531.000000
# mean     135.886794    139.176106    132.512284    136.336178    139.736288
# ...

# %%
#applying PCA on the featurres
from sklearn.decomposition import PCA
x = gray_dataframe.values
pca = PCA(n_components=2)
pca_fit = pca.fit_transform(x)
print('variance:%s' % pca.explained_variance_ratio_)
# Out:
# variance:[0.19217404 0.10926422]

# %%
import matplotlib.pyplot as plt
pca = PCA().fit(x)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('explained variance')
plt.show()

# %%
import matplotlib.pyplot as plt
pca = PCA().fit(x)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.xlim([0,150])
plt.ylabel('explained variance')
plt.show()

# %%
x = gray_dataframe.values
pca = PCA(n_components=25)
pca_fit = pca.fit_transform(x)
print('variance:%s' % pca.explained_variance_ratio_)
# Out:
# variance:[0.19217404 0.10926422 0.09999525 0.08451201 0.03481803 0.0301873
#  0.02370788 0.01839512 0.01745605 0.01669453 0.01040394 0.01019665
#  0.00968025 0.00937107 0.00897885 0.00767349 0.00703363 0.00652895
#  0.00574254 0.00564685 0.00550758 0.00516532 0.00486037 0.00465871
#  0.00449716]

# %%
pca_fit.shape
# Out:
# (14531, 25)
